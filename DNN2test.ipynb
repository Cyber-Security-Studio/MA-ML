# %%
from __future__ import print_function
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
np.random.seed(1337)  # for reproducibility
from keras.preprocessing import sequence
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Embedding
from keras.layers import LSTM, SimpleRNN, GRU
from keras.datasets import imdb
from keras.utils.np_utils import to_categorical
from sklearn.metrics import (precision_score, recall_score,f1_score, accuracy_score,mean_squared_error,mean_absolute_error)
from sklearn import metrics
from sklearn.preprocessing import Normalizer
import h5py
from keras import callbacks
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
traindata = pd.read_csv('/content/drive/MyDrive/Colab Results/Data/Training.csv', header=None)
testdata = pd.read_csv('/content/drive/MyDrive/Colab Results/Data/Testing.csv', header=None)

# %%
X = traindata.iloc[:,1:42]
Y = traindata.iloc[:,0]
C = testdata.iloc[:,0]
T = testdata.iloc[:,1:42]

scaler = Normalizer().fit(X)
trainX = scaler.transform(X)

scaler = Normalizer().fit(T)
testT = scaler.transform(T)

y_train = np.array(Y)
y_test = np.array(C)

X_train = np.array(trainX)
X_test = np.array(testT)


batch_size = 64

# %%
# 1. define the network
model = Sequential()
model.add(Dense(1024,input_dim=41,activation='relu'))  
model.add(Dropout(0.01))
model.add(Dense(768,activation='relu'))  
model.add(Dropout(0.01))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
# try using different optimizers and different optimizer configs
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
checkpointer = callbacks.ModelCheckpoint(filepath="kddresults/dnn2layer/checkpoint-{epoch:02d}.hdf5", verbose=1, save_best_only=True, monitor='loss')
csv_logger = CSVLogger('kddresults/dnn2layer/training_set_dnnanalysis.csv',separator=',', append=False)
model.fit(X_train, y_train, batch_size=batch_size, epochs=100, callbacks=[checkpointer,csv_logger])
model.save("kddresults/dnn2layer/dnn2layer_model.hdf5")
# Out:
# Epoch 1/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0130 - accuracy: 0.9957
# Epoch 00001: loss improved from inf to 0.01304, saving model to kddresults/dnn2layer/checkpoint-01.hdf5
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0130 - accuracy: 0.9957
# Epoch 2/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9979
# Epoch 00002: loss improved from 0.01304 to 0.00705, saving model to kddresults/dnn2layer/checkpoint-02.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0071 - accuracy: 0.9979
# Epoch 3/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9981
# Epoch 00003: loss improved from 0.00705 to 0.00610, saving model to kddresults/dnn2layer/checkpoint-03.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0061 - accuracy: 0.9981
# Epoch 4/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9983
# Epoch 00004: loss improved from 0.00610 to 0.00536, saving model to kddresults/dnn2layer/checkpoint-04.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0054 - accuracy: 0.9983
# Epoch 5/100
# 7712/7720 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9986
# Epoch 00005: loss improved from 0.00536 to 0.00476, saving model to kddresults/dnn2layer/checkpoint-05.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0048 - accuracy: 0.9986
# Epoch 6/100
# 7714/7720 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 0.9987
# Epoch 00006: loss improved from 0.00476 to 0.00423, saving model to kddresults/dnn2layer/checkpoint-06.hdf5
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0042 - accuracy: 0.9987
# Epoch 7/100
# 7713/7720 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9988
# Epoch 00007: loss improved from 0.00423 to 0.00410, saving model to kddresults/dnn2layer/checkpoint-07.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0041 - accuracy: 0.9988
# Epoch 8/100
# 7714/7720 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9989
# Epoch 00008: loss improved from 0.00410 to 0.00385, saving model to kddresults/dnn2layer/checkpoint-08.hdf5
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0039 - accuracy: 0.9989
# Epoch 9/100
# 7715/7720 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.9989
# Epoch 00009: loss improved from 0.00385 to 0.00361, saving model to kddresults/dnn2layer/checkpoint-09.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 10/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0035 - accuracy: 0.9990
# Epoch 00010: loss improved from 0.00361 to 0.00349, saving model to kddresults/dnn2layer/checkpoint-10.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 11/100
# 7711/7720 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9990
# Epoch 00011: loss improved from 0.00349 to 0.00328, saving model to kddresults/dnn2layer/checkpoint-11.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 12/100
# 7717/7720 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9991
# Epoch 00012: loss improved from 0.00328 to 0.00310, saving model to kddresults/dnn2layer/checkpoint-12.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0031 - accuracy: 0.9991
# Epoch 13/100
# 7714/7720 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9991
# Epoch 00013: loss improved from 0.00310 to 0.00304, saving model to kddresults/dnn2layer/checkpoint-13.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0030 - accuracy: 0.9991
# Epoch 14/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9991
# Epoch 00014: loss improved from 0.00304 to 0.00291, saving model to kddresults/dnn2layer/checkpoint-14.hdf5
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0029 - accuracy: 0.9991
# Epoch 15/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9991
# Epoch 00015: loss improved from 0.00291 to 0.00278, saving model to kddresults/dnn2layer/checkpoint-15.hdf5
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 16/100
# 7713/7720 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9991
# Epoch 00016: loss improved from 0.00278 to 0.00276, saving model to kddresults/dnn2layer/checkpoint-16.hdf5
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 17/100
# 7711/7720 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9992
# Epoch 00017: loss improved from 0.00276 to 0.00264, saving model to kddresults/dnn2layer/checkpoint-17.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 18/100
# 7713/7720 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9991
# Epoch 00018: loss improved from 0.00264 to 0.00259, saving model to kddresults/dnn2layer/checkpoint-18.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 19/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9992
# Epoch 00019: loss improved from 0.00259 to 0.00243, saving model to kddresults/dnn2layer/checkpoint-19.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 20/100
# 7710/7720 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9992
# Epoch 00020: loss did not improve from 0.00243
# 7720/7720 [==============================] - 35s 5ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 21/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9992
# Epoch 00021: loss improved from 0.00243 to 0.00238, saving model to kddresults/dnn2layer/checkpoint-21.hdf5
# 7720/7720 [==============================] - 34s 4ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 22/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9993
# Epoch 00022: loss improved from 0.00238 to 0.00223, saving model to kddresults/dnn2layer/checkpoint-22.hdf5
# 7720/7720 [==============================] - 34s 4ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 23/100
# 7717/7720 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9992
# Epoch 00023: loss did not improve from 0.00223
# 7720/7720 [==============================] - 36s 5ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 24/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9993
# Epoch 00024: loss improved from 0.00223 to 0.00216, saving model to kddresults/dnn2layer/checkpoint-24.hdf5
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 25/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 00025: loss improved from 0.00216 to 0.00214, saving model to kddresults/dnn2layer/checkpoint-25.hdf5
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 26/100
# 7717/7720 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9993
# Epoch 00026: loss did not improve from 0.00214
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 27/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 00027: loss improved from 0.00214 to 0.00209, saving model to kddresults/dnn2layer/checkpoint-27.hdf5
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 28/100
# 7720/7720 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9993
# Epoch 00028: loss did not improve from 0.00209
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 29/100
# 7711/7720 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9993
# Epoch 00029: loss improved from 0.00209 to 0.00205, saving model to kddresults/dnn2layer/checkpoint-29.hdf5
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 30/100
# 7712/7720 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 00030: loss did not improve from 0.00205
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 31/100
# 7712/7720 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994
# Epoch 00031: loss improved from 0.00205 to 0.00184, saving model to kddresults/dnn2layer/checkpoint-31.hdf5
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 32/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 00032: loss did not improve from 0.00184
# 7720/7720 [==============================] - 37s 5ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 33/100
# 7715/7720 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 00033: loss did not improve from 0.00184
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 34/100
# 7712/7720 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 00034: loss did not improve from 0.00184
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 35/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994
# Epoch 00035: loss improved from 0.00184 to 0.00182, saving model to kddresults/dnn2layer/checkpoint-35.hdf5
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 36/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994
# Epoch 00036: loss improved from 0.00182 to 0.00182, saving model to kddresults/dnn2layer/checkpoint-36.hdf5
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 37/100
# 7714/7720 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 00037: loss did not improve from 0.00182
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 38/100
# 7712/7720 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9994
# Epoch 00038: loss improved from 0.00182 to 0.00174, saving model to kddresults/dnn2layer/checkpoint-38.hdf5
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0017 - accuracy: 0.9994
# Epoch 39/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9995
# Epoch 00039: loss improved from 0.00174 to 0.00169, saving model to kddresults/dnn2layer/checkpoint-39.hdf5
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 40/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9995
# Epoch 00040: loss did not improve from 0.00169
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 41/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9995
# Epoch 00041: loss did not improve from 0.00169
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 42/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 00042: loss improved from 0.00169 to 0.00159, saving model to kddresults/dnn2layer/checkpoint-42.hdf5
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 43/100
# 7714/7720 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 00043: loss improved from 0.00159 to 0.00157, saving model to kddresults/dnn2layer/checkpoint-43.hdf5
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 44/100
# 7715/7720 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 00044: loss did not improve from 0.00157
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 45/100
# 7717/7720 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 00045: loss did not improve from 0.00157
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 46/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9995
# Epoch 00046: loss improved from 0.00157 to 0.00149, saving model to kddresults/dnn2layer/checkpoint-46.hdf5
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 47/100
# 7714/7720 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9995
# Epoch 00047: loss did not improve from 0.00149
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 48/100
# 7713/7720 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 00048: loss did not improve from 0.00149
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 49/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995
# Epoch 00049: loss did not improve from 0.00149
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 50/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 00050: loss improved from 0.00149 to 0.00148, saving model to kddresults/dnn2layer/checkpoint-50.hdf5
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0015 - accuracy: 0.9996
# Epoch 51/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9995
# Epoch 00051: loss improved from 0.00148 to 0.00144, saving model to kddresults/dnn2layer/checkpoint-51.hdf5
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 52/100
# 7720/7720 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9995
# Epoch 00052: loss improved from 0.00144 to 0.00139, saving model to kddresults/dnn2layer/checkpoint-52.hdf5
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 53/100
# 7715/7720 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9995
# Epoch 00053: loss did not improve from 0.00139
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 54/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 00054: loss improved from 0.00139 to 0.00137, saving model to kddresults/dnn2layer/checkpoint-54.hdf5
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0014 - accuracy: 0.9996
# Epoch 55/100
# 7713/7720 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00055: loss improved from 0.00137 to 0.00133, saving model to kddresults/dnn2layer/checkpoint-55.hdf5
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 56/100
# 7717/7720 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 00056: loss did not improve from 0.00133
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0015 - accuracy: 0.9996
# Epoch 57/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00057: loss improved from 0.00133 to 0.00131, saving model to kddresults/dnn2layer/checkpoint-57.hdf5
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 58/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 00058: loss did not improve from 0.00131
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0015 - accuracy: 0.9996
# Epoch 59/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00059: loss improved from 0.00131 to 0.00129, saving model to kddresults/dnn2layer/checkpoint-59.hdf5
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 60/100
# 7714/7720 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9995
# Epoch 00060: loss did not improve from 0.00129
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0013 - accuracy: 0.9995
# Epoch 61/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 00061: loss improved from 0.00129 to 0.00122, saving model to kddresults/dnn2layer/checkpoint-61.hdf5
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 62/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00062: loss did not improve from 0.00122
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 63/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 00063: loss did not improve from 0.00122
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0014 - accuracy: 0.9996
# Epoch 64/100
# 7712/7720 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00064: loss did not improve from 0.00122
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 65/100
# 7713/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 00065: loss improved from 0.00122 to 0.00118, saving model to kddresults/dnn2layer/checkpoint-65.hdf5
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 66/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 00066: loss did not improve from 0.00118
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 67/100
# 7714/7720 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 00067: loss did not improve from 0.00118
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0015 - accuracy: 0.9996
# Epoch 68/100
# 7717/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 00068: loss did not improve from 0.00118
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 69/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 00069: loss did not improve from 0.00118
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 70/100
# 7713/7720 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00070: loss did not improve from 0.00118
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 71/100
# 7713/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 00071: loss did not improve from 0.00118
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 72/100
# 7717/7720 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00072: loss did not improve from 0.00118
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 73/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996
# Epoch 00073: loss did not improve from 0.00118
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0016 - accuracy: 0.9996
# Epoch 74/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 00074: loss did not improve from 0.00118
# 7720/7720 [==============================] - 38s 5ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 75/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 00075: loss improved from 0.00118 to 0.00118, saving model to kddresults/dnn2layer/checkpoint-75.hdf5
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 76/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 00076: loss did not improve from 0.00118
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 77/100
# 7714/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 00077: loss improved from 0.00118 to 0.00116, saving model to kddresults/dnn2layer/checkpoint-77.hdf5
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 78/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00078: loss improved from 0.00116 to 0.00109, saving model to kddresults/dnn2layer/checkpoint-78.hdf5
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 79/100
# 7715/7720 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00079: loss did not improve from 0.00109
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 80/100
# 7717/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 00080: loss did not improve from 0.00109
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 81/100
# 7712/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 00081: loss did not improve from 0.00109
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 82/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9997
# Epoch 00082: loss improved from 0.00109 to 0.00103, saving model to kddresults/dnn2layer/checkpoint-82.hdf5
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0010 - accuracy: 0.9997
# Epoch 83/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9997
# Epoch 00083: loss did not improve from 0.00103
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0010 - accuracy: 0.9997
# Epoch 84/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00084: loss did not improve from 0.00103
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 85/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 00085: loss did not improve from 0.00103
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 86/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00086: loss did not improve from 0.00103
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 87/100
# 7713/7720 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00087: loss did not improve from 0.00103
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 88/100
# 7713/7720 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 00088: loss did not improve from 0.00103
# 7720/7720 [==============================] - 39s 5ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 89/100
# 7717/7720 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00089: loss did not improve from 0.00103
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 90/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00090: loss did not improve from 0.00103
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 91/100
# 7716/7720 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00091: loss did not improve from 0.00103
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 92/100
# 7717/7720 [============================>.] - ETA: 0s - loss: 9.9241e-04 - accuracy: 0.9997
# Epoch 00092: loss improved from 0.00103 to 0.00099, saving model to kddresults/dnn2layer/checkpoint-92.hdf5
# 7720/7720 [==============================] - 41s 5ms/step - loss: 9.9214e-04 - accuracy: 0.9997
# Epoch 93/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9997
# Epoch 00093: loss did not improve from 0.00099
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0010 - accuracy: 0.9997
# Epoch 94/100
# 7714/7720 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00094: loss did not improve from 0.00099
# 7720/7720 [==============================] - 41s 5ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 95/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9997
# Epoch 00095: loss did not improve from 0.00099
# 7720/7720 [==============================] - 41s 5ms/step - loss: 0.0010 - accuracy: 0.9997
# Epoch 96/100
# 7718/7720 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00096: loss did not improve from 0.00099
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 97/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 9.5711e-04 - accuracy: 0.9997
# Epoch 00097: loss improved from 0.00099 to 0.00096, saving model to kddresults/dnn2layer/checkpoint-97.hdf5
# 7720/7720 [==============================] - 40s 5ms/step - loss: 9.5710e-04 - accuracy: 0.9997
# Epoch 98/100
# 7720/7720 [==============================] - ETA: 0s - loss: 9.9455e-04 - accuracy: 0.9997
# Epoch 00098: loss did not improve from 0.00096
# 7720/7720 [==============================] - 40s 5ms/step - loss: 9.9455e-04 - accuracy: 0.9997
# Epoch 99/100
# 7719/7720 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00099: loss did not improve from 0.00096
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 100/100
# 7712/7720 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00100: loss did not improve from 0.00096
# 7720/7720 [==============================] - 40s 5ms/step - loss: 0.0011 - accuracy: 0.9997

# %%
from sklearn.metrics import confusion_matrix
import os
for file in os.listdir("/content/drive/MyDrive/Colab Results/kddresults/dnn2layer/"):
  if not file.endswith(".hdf5"):
        print(os.path.join("/content/drive/MyDrive/Colab Results/kddresults/dnn2layer/", file))
# Out:
# /content/drive/MyDrive/Colab Results/kddresults/dnn2layer/training_set_dnnanalysis.csv

# %%
score = []
name = []
from sklearn.metrics import confusion_matrix
import os
for file in os.listdir("/content/drive/MyDrive/Colab Results/kddresults/dnn2layer/"):
  if file.endswith(".hdf5"):
    model.load_weights("/content/drive/MyDrive/Colab Results/kddresults/dnn2layer/"+file)
    y_train1 = y_test
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    accuracy = accuracy_score(y_train1, y_pred)
    recall = recall_score(y_train1, y_pred , average="binary")
    precision = precision_score(y_train1, y_pred , average="binary")
    f1 = f1_score(y_train1, y_pred, average="binary")
    print("----------------------------------------------")
    print("accuracy")
    print("%.3f" %accuracy)
    print("recall")
    print("%.3f" %recall)
    print("precision")
    print("%.3f" %precision)
    print("f1score")
    print("%.3f" %f1)
    score.append(accuracy)
    name.append(file)
# Out:
# ----------------------------------------------
# accuracy
# 0.932
# recall
# 0.917
# precision
# 0.998
# f1score
# 0.956
# ----------------------------------------------
# accuracy
# 0.922
# recall
# 0.907
# precision
# 0.996
# f1score
# 0.949
# ----------------------------------------------
# accuracy
# 0.926
# recall
# 0.909
# precision
# 0.999
# f1score
# 0.952
# ----------------------------------------------
# accuracy
# 0.931
# recall
# 0.916
# precision
# 0.998
# f1score
# 0.955
# ----------------------------------------------
# accuracy
# 0.925
# recall
# 0.908
# precision
# 0.999
# f1score
# 0.951
# ----------------------------------------------
# accuracy
# 0.924
# recall
# 0.907
# precision
# 0.999
# f1score
# 0.951
# ----------------------------------------------
# accuracy
# 0.930
# recall
# 0.914
# precision
# 0.998
# f1score
# 0.954
# ----------------------------------------------
# accuracy
# 0.930
# recall
# 0.915
# precision
# 0.998
# f1score
# 0.955
# ----------------------------------------------
# accuracy
# 0.929
# recall
# 0.914
# precision
# 0.998
# f1score
# 0.954
# ----------------------------------------------
# accuracy
# 0.931
# recall
# 0.915
# precision
# 0.999
# f1score
# 0.955
# ----------------------------------------------
# accuracy
# 0.928
# recall
# 0.912
# precision
# 0.998
# f1score
# 0.953
# ----------------------------------------------
# accuracy
# 0.929
# recall
# 0.912
# precision
# 0.999
# f1score
# 0.954
# ----------------------------------------------
# accuracy
# 0.924
# recall
# 0.906
# precision
# 0.999
# f1score
# 0.950
# ----------------------------------------------
# accuracy
# 0.930
# recall
# 0.914
# precision
# 0.999
# f1score
# 0.954
# ----------------------------------------------
# accuracy
# 0.926
# recall
# 0.909
# precision
# 0.999
# f1score
# 0.952
# ----------------------------------------------
# accuracy
# 0.930
# recall
# 0.914
# precision
# 0.999
# f1score
# 0.955
# ----------------------------------------------
# accuracy
# 0.929
# recall
# 0.913
# precision
# 0.999
# f1score
# 0.954
# ----------------------------------------------
# accuracy
# 0.929
# recall
# 0.914
# precision
# 0.998
# f1score
# 0.954
# ----------------------------------------------
# accuracy
# 0.931
# recall
# 0.915
# precision
# 0.999
# f1score
# 0.955
# ----------------------------------------------
# accuracy
# 0.923
# recall
# 0.906
# precision
# 0.999
# f1score
# 0.950
# ----------------------------------------------
# accuracy
# 0.921
# recall
# 0.906
# precision
# 0.996
# f1score
# 0.949
# ----------------------------------------------
# accuracy
# 0.925
# recall
# 0.908
# precision
# 0.999
# f1score
# 0.951
# ----------------------------------------------
# accuracy
# 0.931
# recall
# 0.915
# precision
# 0.999
# f1score
# 0.955
# ----------------------------------------------
# accuracy
# 0.931
# recall
# 0.916
# precision
# 0.998
# f1score
# 0.955
# ----------------------------------------------
# accuracy
# 0.928
# recall
# 0.912
# precision
# 0.998
# f1score
# 0.953
# ----------------------------------------------
# accuracy
# 0.925
# recall
# 0.908
# precision
# 0.998
# f1score
# 0.951
# ----------------------------------------------
# accuracy
# 0.928
# recall
# 0.912
# precision
# 0.999
# f1score
# 0.953
# ----------------------------------------------
# accuracy
# 0.928
# recall
# 0.912
# precision
# 0.999
# f1score
# 0.953
# ----------------------------------------------
# accuracy
# 0.927
# recall
# 0.911
# precision
# 0.999
# f1score
# 0.953
# ----------------------------------------------
# accuracy
# 0.927
# recall
# 0.911
# precision
# 0.999
# f1score
# 0.953
# ----------------------------------------------
# accuracy
# 0.924
# recall
# 0.907
# precision
# 0.999
# f1score
# 0.950
# ----------------------------------------------
# accuracy
# 0.930
# recall
# 0.914
# precision
# 0.999
# f1score
# 0.954
# ----------------------------------------------
# accuracy
# 0.928
# recall
# 0.912
# precision
# 0.999
# f1score
# 0.953
# ----------------------------------------------
# accuracy
# 0.924
# recall
# 0.907
# precision
# 0.999
# f1score
# 0.951
# ----------------------------------------------
# accuracy
# 0.931
# recall
# 0.915
# precision
# 0.999
# f1score
# 0.955
# ----------------------------------------------
# accuracy
# 0.925
# recall
# 0.908
# precision
# 0.998
# f1score
# 0.951
# ----------------------------------------------
# accuracy
# 0.927
# recall
# 0.911
# precision
# 0.999
# f1score
# 0.953
# ----------------------------------------------
# accuracy
# 0.927
# recall
# 0.910
# precision
# 0.999
# f1score
# 0.952
# ----------------------------------------------
# accuracy
# 0.929
# recall
# 0.913
# precision
# 0.999
# f1score
# 0.954
# ----------------------------------------------
# accuracy
# 0.925
# recall
# 0.908
# precision
# 0.999
# f1score
# 0.951
# ----------------------------------------------
# accuracy
# 0.931
# recall
# 0.915
# precision
# 0.999
# f1score
# 0.955
# ----------------------------------------------
# accuracy
# 0.927
# recall
# 0.910
# precision
# 0.998
# f1score
# 0.952
# ----------------------------------------------
# accuracy
# 0.926
# recall
# 0.909
# precision
# 0.999
# f1score
# 0.952
# ----------------------------------------------
# accuracy
# 0.927
# recall
# 0.911
# precision
# 0.998
# f1score
# 0.953
# ----------------------------------------------
# accuracy
# 0.929
# recall
# 0.914
# precision
# 0.998
# f1score
# 0.954
# ----------------------------------------------
# accuracy
# 0.926
# recall
# 0.910
# precision
# 0.999
# f1score
# 0.952
# ----------------------------------------------
# accuracy
# 0.924
# recall
# 0.907
# precision
# 0.999
# f1score
# 0.951
# ----------------------------------------------
# accuracy
# 0.930
# recall
# 0.914
# precision
# 0.999
# f1score
# 0.955
# ----------------------------------------------
# accuracy
# 0.925
# recall
# 0.908
# precision
# 0.999
# f1score
# 0.951

# %%
print(type(name))
print(type(score))

print(name[0])
# Out:
# <class 'list'>
# <class 'list'>
# checkpoint-39.hdf5

# %%
model.load_weights("/content/drive/MyDrive/Colab Results/kddresults/dnn2layer/"+name[score.index(max(score))])
pred = (model.predict(X_test) > 0.5).astype("int32")
#proba = model.predict_proba(X_test)
np.savetxt("/content/drive/MyDrive/Colab Results/dnnres/dnn2predicted.txt", pred)
np.savetxt("/content/drive/MyDrive/Colab Results/dnnres/dnn2probability.txt", proba)

accuracy = accuracy_score(y_test, pred)
recall = recall_score(y_test, pred , average="binary")
precision = precision_score(y_test, pred , average="binary")
f1 = f1_score(y_test, pred, average="binary")


print("----------------------------------------------")
print("accuracy")
print("%.3f" %accuracy)
print("precision")
print("%.3f" %precision)
print("recall")
print("%.3f" %recall)
print("f1score")
print("%.3f" %f1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-d4d9814740f9> in <module>()
#       2 pred = (model.predict(X_test) > 0.5).astype("int32")
#       3 #proba = model.predict_proba(X_test)
# ----> 4 np.savetxt("dnnres/dnn2predicted.txt", pred)
#       5 np.savetxt("dnnres/dnn2probability.txt", proba)
#       6
#
# <__array_function__ internals> in savetxt(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1355     if _is_string_like(fname):
#    1356         # datasource doesn't support creating a new file ...
# -> 1357         open(fname, 'wt').close()
#    1358         fh = np.lib._datasource.open(fname, 'wt', encoding=encoding)
#    1359         own_fh = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dnnres/dnn2predicted.txt'
